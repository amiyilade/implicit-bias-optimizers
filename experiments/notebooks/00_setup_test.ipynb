# %% [markdown]
# <a href="https://colab.research.google.com/github/amiyilade/implicit-bias-optimizers/blob/main/experiments/notebooks/00_setup_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone Github repo

import os
import sys

repo = "implicit-bias-optimizers"
repo_path = os.path.abspath(repo)

os.system("git clone https://github.com/amiyilade/implicit-bias-optimizers.git")

if os.path.isdir(repo) and repo_path not in sys.path:
  sys.path.append(repo_path)
  print("✅ Cloned Github repo")
# Out:
# ✅ Cloned Github repo

# %%
# Connect to Google Drive

from google.colab import drive

drive.mount('/content/drive')

RESULTS_DIR = '/content/drive/MyDrive/implicit_bias_results' # Ensure this folder is shared with you and added to your My Drive (right-click on the folder → Add shortcut to Drive)

if not os.path.isdir(RESULTS_DIR):
    raise RuntimeError(
        "Shared results folder not found. "
        "Ensure it is shared with you and added to your My Drive."
    )

print(f"✅ Connected to Drive! Results will save to: {RESULTS_DIR}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Connected to Drive! Results will save to: /content/drive/MyDrive/implicit_bias_results

# %%
# Test PyTorch

import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
  print(f"GPU: {torch.cuda.get_device_name(0)}")
  print("✅ PyTorch works!")
# Out:
# PyTorch version: 2.9.0+cpu
# CUDA available: False

# %%
# Test our imports (should fail by 24 Dec, will write the code later)

try:
  from models.architectures import LinearNetprint
  print("✅ Imports work!")
except:
  print("⚠️ Imports not working!")
# Out:
# ⚠️ Imports not working!
